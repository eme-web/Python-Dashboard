# %%
import pandas as pd 
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():
    
    df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
    pn.state.cache['data'] = df.copy()
    
else:
    
    df = pn.state.cache['data']

# %%
df.head()
# Out:
#   iso_code      country  year    co2  co2_per_capita  trade_co2  cement_co2  \
# 0      AFG  Afghanistan  1949  0.015           0.002        NaN         NaN
# 1      AFG  Afghanistan  1950  0.084           0.011        NaN         NaN
# 2      AFG  Afghanistan  1951  0.092           0.012        NaN         NaN
# 3      AFG  Afghanistan  1952  0.092           0.012        NaN         NaN
# 4      AFG  Afghanistan  1953  0.106           0.013        NaN         NaN
#
#    cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0                    NaN     0.015                0.002  ...
# 1                    NaN     0.021                0.003  ...
# 2                    NaN     0.026                0.003  ...
# 3                    NaN     0.032                0.004  ...
# 4                    NaN     0.038                0.005  ...
#
#    ghg_excluding_lucf_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0                            NaN      NaN                 NaN            NaN
# 1                            NaN      NaN                 NaN            NaN
# 2                            NaN      NaN                 NaN            NaN
# 3                            NaN      NaN                 NaN            NaN
# 4                            NaN      NaN                 NaN            NaN
#
#    nitrous_oxide_per_capita  population           gdp  \
# 0                       NaN   7624058.0           NaN
# 1                       NaN   7752117.0  9.421400e+09
# 2                       NaN   7840151.0  9.692280e+09
# 3                       NaN   7935996.0  1.001733e+10
# 4                       NaN   8039684.0  1.063052e+10
#
#    primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                         NaN                NaN             NaN
# 1                         NaN                NaN             NaN
# 2                         NaN                NaN             NaN
# 3                         NaN                NaN             NaN
# 4                         NaN                NaN             NaN
#
# [5 rows x 60 columns]

# %%
df[df['country'] == 'North America']
# Out:
#       iso_code        country  year       co2  co2_per_capita  trade_co2  \
# 16785      NaN  North America  1785     0.004             NaN        NaN
# 16786      NaN  North America  1786     0.004             NaN        NaN
# 16787      NaN  North America  1787     0.004             NaN        NaN
# 16788      NaN  North America  1788     0.004             NaN        NaN
# 16789      NaN  North America  1789     0.004             NaN        NaN
# ...        ...            ...   ...       ...             ...        ...
# 17016      NaN  North America  2016  6471.360          11.353    309.904
# 17017      NaN  North America  2017  6412.982          11.155    335.009
# 17018      NaN  North America  2018  6588.630          11.366    345.915
# 17019      NaN  North America  2019  6460.726          11.056    354.353
# 17020      NaN  North America  2020  5775.159           9.805        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 16785         NaN                    NaN     0.004                  NaN  ...
# 16786         NaN                    NaN     0.004                  NaN  ...
# 16787         NaN                    NaN     0.004                  NaN  ...
# 16788         NaN                    NaN     0.004                  NaN  ...
# 16789         NaN                    NaN     0.004                  NaN  ...
# ...           ...                    ...       ...                  ...  ...
# 17016      70.858                  0.124  1509.631                2.648  ...
# 17017      72.914                  0.127  1467.602                2.553  ...
# 17018      74.787                  0.129  1398.979                2.413  ...
# 17019      76.925                  0.132  1214.329                2.078  ...
# 17020      76.870                  0.130   965.430                1.639  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 16785                            NaN      NaN                 NaN
# 16786                            NaN      NaN                 NaN
# 16787                            NaN      NaN                 NaN
# 16788                            NaN      NaN                 NaN
# 16789                            NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 17016                            NaN      NaN                 NaN
# 17017                            NaN      NaN                 NaN
# 17018                            NaN      NaN                 NaN
# 17019                            NaN      NaN                 NaN
# 17020                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita   population  gdp  \
# 16785            NaN                       NaN          NaN  NaN
# 16786            NaN                       NaN          NaN  NaN
# 16787            NaN                       NaN          NaN  NaN
# 16788            NaN                       NaN          NaN  NaN
# 16789            NaN                       NaN          NaN  NaN
# ...              ...                       ...          ...  ...
# 17016            NaN                       NaN  573814461.0  NaN
# 17017            NaN                       NaN  578582963.0  NaN
# 17018            NaN                       NaN  582921781.0  NaN
# 17019            NaN                       NaN  587512621.0  NaN
# 17020            NaN                       NaN  592062319.0  NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 16785                         NaN                NaN             NaN
# 16786                         NaN                NaN             NaN
# 16787                         NaN                NaN             NaN
# 16788                         NaN                NaN             NaN
# 16789                         NaN                NaN             NaN
# ...                           ...                ...             ...
# 17016                         NaN                NaN             NaN
# 17017                         NaN                NaN             NaN
# 17018                         NaN                NaN             NaN
# 17019                         NaN                NaN             NaN
# 17020                         NaN                NaN             NaN
#
# [236 rows x 60 columns]

# %%
df[df['country'] == 'World']
# Out:
#        iso_code country  year        co2  co2_per_capita  trade_co2  \
# 25458  OWID_WRL   World  1750      9.351           0.012        NaN
# 25459  OWID_WRL   World  1751      9.351             NaN        NaN
# 25460  OWID_WRL   World  1752      9.354             NaN        NaN
# 25461  OWID_WRL   World  1753      9.354             NaN        NaN
# 25462  OWID_WRL   World  1754      9.358             NaN        NaN
# ...         ...     ...   ...        ...             ...        ...
# 25724  OWID_WRL   World  2016  35452.459           4.750       -0.0
# 25725  OWID_WRL   World  2017  35925.738           4.760        0.0
# 25726  OWID_WRL   World  2018  36646.140           4.802       -0.0
# 25727  OWID_WRL   World  2019  36702.503           4.758        0.0
# 25728  OWID_WRL   World  2020  34807.259           4.465        0.0
#
#        cement_co2  cement_co2_per_capita   coal_co2  coal_co2_per_capita  ...  \
# 25458         NaN                    NaN      9.351                0.012  ...
# 25459         NaN                    NaN      9.351                  NaN  ...
# 25460         NaN                    NaN      9.354                  NaN  ...
# 25461         NaN                    NaN      9.354                  NaN  ...
# 25462         NaN                    NaN      9.358                  NaN  ...
# ...           ...                    ...        ...                  ...  ...
# 25724    1478.758                  0.198  14360.628                1.924  ...
# 25725    1500.493                  0.199  14453.702                1.915  ...
# 25726    1566.740                  0.205  14718.145                1.929  ...
# 25727    1608.472                  0.208  14573.219                1.889  ...
# 25728    1626.371                  0.209  13976.098                1.793  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 25458                            NaN      NaN                 NaN
# 25459                            NaN      NaN                 NaN
# 25460                            NaN      NaN                 NaN
# 25461                            NaN      NaN                 NaN
# 25462                            NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 25724                          6.184  8172.01               1.095
# 25725                          6.197  8228.64               1.090
# 25726                          6.238  8298.27               1.089
# 25727                            NaN      NaN                 NaN
# 25728                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita    population           gdp  \
# 25458            NaN                       NaN  7.456644e+08           NaN
# 25459            NaN                       NaN           NaN           NaN
# 25460            NaN                       NaN           NaN           NaN
# 25461            NaN                       NaN           NaN           NaN
# 25462            NaN                       NaN           NaN           NaN
# ...              ...                       ...           ...           ...
# 25724        3027.74                     0.406  7.464344e+09  1.071343e+14
# 25725        3078.27                     0.408  7.548183e+09  1.104307e+14
# 25726        3063.75                     0.402  7.631091e+09  1.136302e+14
# 25727            NaN                       NaN  7.713468e+09           NaN
# 25728            NaN                       NaN  7.794799e+09           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 25458                         NaN                NaN             NaN
# 25459                         NaN                NaN             NaN
# 25460                         NaN                NaN             NaN
# 25461                         NaN                NaN             NaN
# 25462                         NaN                NaN             NaN
# ...                           ...                ...             ...
# 25724                  153261.574          20532.490           1.431
# 25725                  156062.390          20675.493           1.413
# 25726                  160036.073          20971.585           1.408
# 25727                  161530.754          20941.391             NaN
# 25728                  154620.430          19836.360             NaN
#
# [271 rows x 60 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Fill NA with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/df['population'],0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# ### CO2 emission over time by continent

# %%
# Define panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1820) 
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1820)

# %%
# Radio buttons for C02 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name= 'Y axis',
    options= ['co2','co2_per_capita',],
    button_type='success'
)

# %%
continents = ['World','Asia','Oceania','Africa','North America','South America','Antarctica']
co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country','year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='121839'>
#   <div class="bk-root" id="f7c4ed69-87ac-4bd3-9fb4-97ac3f2a8698" data-root-id="121839"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"987d0172-19cd-4402-8d2e-f5e046588cf9":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"121841"},{"id":"121846"}],"margin":[0,0,0,0],"name":"Column45604"},"id":"121840","type":"Column"},{"attributes":{"client_comm_id":"69db161e6921469c84eef73d412c3ec6","comm_id":"5f3580530e00409dba79533c4c3ebb96","plot_id":"121839"},"id":"121848","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"121843"},{"id":"121844"}],"margin":[0,0,0,0],"name":"Column45520"},"id":"121842","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer45602","sizing_mode":"stretch_width"},"id":"121845","type":"Spacer"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame45600","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1751&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1752&lt;/td&gt;\n      &lt;td&gt;9.354&lt;/td&gt;\n ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2, line_width=2, title='Co2 emissions by Continents')
co2_plot
# Out:
# <div id='121849'>
#   <div class="bk-root" id="f38d2d79-64de-4c91-8182-5bc51fb85a43" data-root-id="121849"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e377dca8-0a3e-4c96-868a-5648168c6d2d":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"active":0,"button_type":"success","labels":["co2","co2_per_capita"],"margin":[5,10,5,10]},"id":"121854","type":"RadioButtonGroup"},{"attributes":{"click_policy":"mute","coordinates":null,"group":null,"items":[{"id":"121915"},{"id":"121937"}],"location":[0,0],"title":"country"},"id":"121914","type":"Legend"},{"attributes":{"source":{"id":"121896"}},"id":"121903","type":"CDSView"},{"attributes":{},"id":"121870","type":"BasicTicker"},{"attributes":{"label":{"value":"World"},"renderers":[{"id":"121923"}]},"id":"121937","type":"LegendItem"},{"attributes":{},"id":"121897","type":"Selection"},{"attributes":{},"id":"121877","type":"SaveTool"},{"attributes":{"axis_label":"year","coordinates":null,"formatter":{"id":"121891"},"group":null,"major_label_policy":{"id":"121892"},"ticker":{"id":"121870"}},"id":"121869","type":"LinearAxis"},{"attributes":{"end":55.7564,"reset_end":55.7564,"reset_start":-5.064400000000001,"start":-5.064400000000001,"tags":[[["co2","co2",null]]]},"id":"121857","type":"Range1d"},{"attributes":{"data":{"co2":{"__ndarray__":" ...

# %% [markdown]
# ### Table - CO2 emission over time by continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote',page_size = 10, sizing_mode='stretch_width')
co2_table
# Out:
# <div id='123389'>
#   <div class="bk-root" id="5e6cc104-add3-4424-8b43-f5a2f4fface5" data-root-id="123389"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"a7245053-62ad-4e95-bd07-eb92c2135d8a":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"columns":[{"id":"123402"},{"id":"123407"},{"id":"123412"},{"id":"123417"}],"configuration":{"columns":[{"field":"index"},{"field":"country"},{"field":"year"},{"field":"co2"}],"dataTree":false,"selectable":true},"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":57,"name":"","page":1,"page_size":10,"pagination":"remote","select_mode":true,"selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"123397"},"styles":{"data":{},"id":"4596e4986dfe4c4eb38235295e96cef2"},"subscribed_events":["table-edit","cell-click"]},"id":"123420","type":"panel.models.tabulator.DataTabulator"},{"attributes":{},"id":"123406","type":"StringEditor"},{"attributes":{"editor":{"id":"123406"},"field":"country","formatter":{"id":"123405"},"title":"country","width":0},"id":"123407","type":"TableColumn"},{"attributes":{},"id":"123422","type":"UnionRenderers"},{"attributes":{"editor":{"id":"123416"},"field":"co2","formatter":{"id":"123415"},"title":"co2","width":0},"id":"123417","type":"TableColumn"},{"attributes":{},"id":"123416","type":"NumberEditor"},{"attributes":{"children":[{"id":"123392"},{"id":"123395"}],"margin":[0,0,0,0],"name":"Row49646"},"id":"123391","type":"Row"},{"attributes":{"children":[{"id":"123390"}],"margin":[0,0,0,0],"name":"Row49648"},"id":"123389","type":"Row"},{"attributes":{"editor":{"id":"123401"},"field":"index","formatter":{"id":"123399"},"title":"index","width":0},"id": ...
#     var render_items = [{"docid":"a7245053-62ad-4e95-bd07-eb92c2135d8a","root_ids":["123389"],"roots":{"123389":"5e6cc104-add3-4424-8b43-f5a2f4fface5"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined) && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country','year','gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='123439'>
#   <div class="bk-root" id="8a5c9778-039d-4dfa-b8a5-1d47b19bec8f" data-root-id="123439"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"4cf35a3c-50ef-4beb-a60b-c00a9e08aaaf":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"123441"},{"id":"123445"}],"margin":[0,0,0,0],"name":"Column51973"},"id":"123440","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame51969","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Algeria&lt;/td&gt;\n      &lt;td&gt;1925&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.033&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Puerto Rico&lt;/td&gt;\n      &lt;td&gt;1925&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Portugal&lt;/td&gt;\n      &lt;td&gt;1925&lt;/td&gt;\n      &lt;td&gt;2301.833523&lt;/td&gt;\n      &lt;td&gt;3.122&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;Poland&lt;/td&gt;\n      &lt;td&gt;1925&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;48.075&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt; ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', y='co2',by='country',size=80, kind='scatter',
                                                                   legend=False, height=500,width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='123448'>
#   <div class="bk-root" id="fe560b3b-57a9-4961-824b-614fea0d3c02" data-root-id="123448"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"6153f78a-09ef-450e-a8c1-78116d5bd808":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"angle":{"value":0.0},"fill_alpha":{"value":1.0},"fill_color":{"value":"#fc4f30"},"hatch_alpha":{"value":1.0},"hatch_color":{"value":"#fc4f30"},"hatch_scale":{"value":12.0},"hatch_weight":{"value":1.0},"line_alpha":{"value":1.0},"line_cap":{"value":"butt"},"line_color":{"value":"#fc4f30"},"line_dash":{"value":[]},"line_dash_offset":{"value":0},"line_join":{"value":"bevel"},"line_width":{"value":1},"marker":{"value":"circle"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"123704","type":"Scatter"},{"attributes":{"angle":{"value":0.0},"fill_alpha":{"value":1.0},"fill_color":{"value":"#9467bd"},"hatch_alpha":{"value":1.0},"hatch_color":{"value":"#9467bd"},"hatch_scale":{"value":12.0},"hatch_weight":{"value":1.0},"line_alpha":{"value":1.0},"line_cap":{"value":"butt"},"line_color":{"value":"#9467bd"},"line_dash":{"value":[]},"line_dash_offset":{"value":0},"line_join":{"value":"bevel"},"line_width":{"value":1},"marker":{"value":"circle"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"123965","type":"Scatter"},{"attributes":{"coordinates":null,"data_source":{"id":"123615"},"glyph":{"id":"123618"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"123620"},"nonselection_glyph":{"id":"123619"},"selection_glyph":{"id":"123623"},"view":{"id":"123622"}},"id":"123621","type":"GlyphRenderer"},{"attributes":{"coordinates":null," ...

# %% [markdown]
# ### Bar Chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name= 'Y axis',
    options=['coal_co2','oil_co2','gas_co2'],
    buttton_types='success'
)

continents_excl_world = ['Asia','Oceania','Europe','Africa','North America','South America','Antarctica']
co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year','country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)
# Out:
# WARNING:param.Y axis: Setting non-parameter attribute buttton_types=success using a mechanism intended only for parameters

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', x='country', y=yaxis_co2_source, title='CO2 Source by Continent')
co2_source_bar_plot
# Out:
# <div id='126175'>
#   <div class="bk-root" id="ac20c07b-788b-42a8-9426-08d3907769ea" data-root-id="126175"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c6fab51a-96cc-402d-b276-3f1eb233ebdc":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"126203","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"126206"}},"id":"126204","type":"BoxZoomTool"},{"attributes":{"children":[{"id":"126176"}],"margin":[0,0,0,0],"name":"Row60047"},"id":"126175","type":"Row"},{"attributes":{"fill_color":{"value":"#30a2da"},"hatch_color":{"value":"#30a2da"},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"126217","type":"VBar"},{"attributes":{"children":[{"id":"126179"},{"id":"126180"}],"margin":[0,0,0,0],"name":"Column60035"},"id":"126178","type":"Column"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#30a2da"},"hatch_alpha":{"value":0.1},"hatch_color":{"value":"#30a2da"},"line_alpha":{"value":0.1},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"126218","type":"VBar"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#30a2da"},"hatch_alpha":{"value":0.2},"hatch_color":{"value":"#30a2da"},"line_alpha":{"value":0.2},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"126219","type":"VBar"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year slider","value":1925},"id":"126179","type":"Slider"},{"attributes":{"axis":{"id":"126197"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":null},"id":"126200","type":"Grid"},{"attributes":{"children":[{"id":"126178"},{"id":"126181"}]," ...

# %% [markdown]
# ### Creating Dashboard

# %%
# Layout Using Template
template = pn.template.FastListTemplate(
    title = 'World CO2 Emission Dashboard',
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"),
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate "),
             pn.pane.PNG('https://climatereanalyzer.org/wx_frames/gfs/ds/gfs_nh-sat8_t2_1-day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2,co2_plot.panel(width=700), margin=(0,25)),
                co2_table.panel(width=500)),
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600),margin=(0,25)),
                 pn.Column(yaxis_co2_source,co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
#template.servable();
# Out:
# Launching server at http://localhost:54970
